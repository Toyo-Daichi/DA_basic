# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./oscillation_EnKF.csv')

# %%
df
# Out:
#      timestep    x_true     x_sim      x_da    v_true     v_sim      v_da  \
# 0         0.0  5.000000  4.000000  4.008617  0.000000  1.000000  1.000000
# 1         0.2  4.953404  4.156569  4.165105 -0.484615  0.544835  0.544000
# 2         0.4  4.813301  4.223447  5.067900 -0.932015  0.105206 -0.058308
# 3         0.6  4.587777  4.204481  5.009368 -1.335649 -0.311242 -0.545570
# 4         0.8  4.286112  4.104965  4.680526 -1.690190 -0.697752 -0.924719
# 5         1.0  3.918532  3.931453  4.457654 -1.991570 -1.048538 -1.315976
# 6         1.2  3.495956  3.691560  4.074453 -2.236989 -1.358838 -1.603844
# 7         1.4  3.029745  3.393752  3.725584 -2.424891 -1.624951 -1.890536
# 8         1.6  2.531454  3.047135  3.211827 -2.554928 -1.844243 -2.010462
# 9         1.8  2.012600  2.661238  2.792175 -2.627895 -2.015143 -2.186110
# 10        2.0  1.484437  2.245810  2.317538 -2.645650 -2.137111 -2.264949
# 11        2.2  0.957755  1.810610  1.856889 -2.611016 -2.210584 -2.336749
# 12        2.4  0.442694  1.365224  1.383403 -2.527671 -2.236919 -2.340716
# 13        2.6 -0.051410  0.918883  0.916772 -2.400029 -2.218309 -2.316864
# 14        2.8 -0.516167  0.480310  0.453867 -2.233109 -2.157693 -2.272091
# 15        3.0 -0.944236  0.057573  0.009202 -2.032405 -2.058660 -2.162776
# 16        3.2 -1.329410 -0.342026 -0.435068 -1.803755 -1.925336 -2.051575
# 17        3.4 -1.666672 -0.712058 -0.828703 -1.553199 -1.762278 -1.870981
# 18        3.6 -1.952221 -1.047032 -1.224120 -1.286861 -1.574357 -1.691089
# 19        3.8 -2.183481 -1.342458 -1.540523 -1.010818 -1.366648 -1.458340
# 20        4.0 -2.359075 -1.594866 -1.845932 -0.730985 -1.144321 -1.222117
# 21        4.2 -2.478789 -1.801825 -2.065632 -0.453015 -0.912531 -0.960744
# 22        4.4 -2.543503 -1.961924 -2.232618 -0.182197 -0.676322 -0.695712
# 23        4.6 -2.555118 -2.074743 -2.346673  0.076621 -0.440533 -0.432378
# 24        4.8 -2.516453 -2.140803 -2.408618  0.319101 -0.209718 -0.175758
# 25        5.0 -2.431145 -2.161505 -2.420242  0.541472  0.011925  0.069552
# 26        5.2 -2.303527 -2.139050 -2.384204  0.740571  0.220620  0.299436
# 27        5.4 -2.138503 -2.076349 -2.303941  0.913867  0.413057  0.510316
# 28        5.6 -1.941424 -1.976930 -2.183547  1.059476  0.586433  0.699189
# 29        5.8 -1.717956 -1.844828 -2.027663  1.176159  0.738475  0.863648
# 30        6.0 -1.473952 -1.684485 -1.841352  1.263309  0.867454  1.001902
# 31        6.2 -1.215329 -1.500635 -1.629977  1.320929  0.972189  1.112770
# 32        6.4 -0.947946 -1.298195 -1.399081  1.349596  1.052039  1.195670
# 33        6.6 -0.677498 -1.082163 -1.154266  1.350412  1.106879  1.250598
# 34        6.8 -0.409412 -0.857514 -0.901086  1.324961  1.137081  1.278091
# 35        7.0 -0.148758 -0.629104 -0.644936  1.275243  1.143472  1.279190
# 36        7.2  0.099829 -0.401584 -0.390959  1.203616  1.127293  1.255389
# 37        7.4  0.332215 -0.179320 -0.143964  1.112729  1.090154  1.208577
# 38        7.6  0.544817  0.033673  0.091656  1.005451  1.033978  1.140984
# 39        7.8  0.734642  0.233792  0.311977  0.884804  0.960948  1.055114
# 40        8.0  0.899311  0.417889  0.513599  0.753900  0.873450  0.953685
#
#     obs_data
# 0       None
# 1       None
# 2      5.157
# 3       None
# 4      4.424
# 5       None
# 6      3.740
# 7       None
# 8      2.165
# 9       None
# 10     1.591
# 11      None
# 12     0.281
# 13      None
# 14    -0.872
# 15      None
# 16    -1.386
# 17      None
# 18    -1.966
# 19      None
# 20    -2.330
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
# 30      None
# 31      None
# 32      None
# 33      None
# 34      None
# 35      None
# 36      None
# 37      None
# 38      None
# 39      None
# 40      None

# %%
timestep = df[' timestep'].tolist()

# %%
x_true, x_sim, x_da = df[' x_true'].tolist(), df[' x_sim'].tolist(), df[' x_da'].tolist()
v_true, v_sim, v_da = df[' v_true'].tolist(), df[' v_sim'].tolist(), df[' v_da'].tolist()

# %%
obs = df.loc[ :, [' timestep', ' obs_data']]
obs = obs[obs[' obs_data'] != 'None']
obs_timestep, obs_score = obs[ ' timestep'].tolist(), obs[ ' obs_data'].tolist()
obs_score = [float(s) for s in obs_score]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(timestep, x_true, 'b:', label='True')
ax.plot(timestep, x_sim, 'r:', label='Simulation')
ax.plot(timestep, x_da, 'g:', label='Data assimlation')
ax.scatter(obs_timestep, obs_score, marker='*', color='b', label='Observation')
ax.legend()
ax.set_xlabel("time [seconds]")
ax.set_ylabel("damped oscillation [x(m)]")
ax.set_ylim(-5.5, 5.5)
plt.savefig('./tmp_fullx.png')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(timestep[0:30], x_true[0:30], 'b:', label='True')
ax.plot(timestep[0:30], x_sim[0:30], 'r:', label='Simulation')
ax.plot(timestep[0:30], x_da[0:30], 'g:', label='Data assimlation')
ax.scatter(obs_timestep[0:15], obs_score[0:15], marker='*', color='b', label='Observation')
ax.set_xlabel("time [seconds]")
ax.set_ylabel("damped oscillation [x(m)]")
ax.set_ylim(-5.5, 5.5)
plt.savefig('./tmp_shortx.png')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(timestep, v_true, 'b:', label='True')
ax.plot(timestep, v_sim, 'r:', label='Simulation')
ax.plot(timestep, v_da, 'g:', label='Data assimlation')
ax.legend()
ax.set_xlabel("time [seconds]")
ax.set_ylabel("damped oscillation [v(m/s)]")
ax.set_ylim(-3.5, 3.5)
plt.savefig('./tmp_fullv.png')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(timestep[0:30], v_true[0:30], 'b:', label='True')
ax.plot(timestep[0:30], v_sim[0:30], 'r:', label='Simulation')
ax.plot(timestep[0:30], v_da[0:30], 'g:', label='Data assimlation')
ax.legend()
ax.set_xlabel("time [seconds]")
ax.set_ylabel("damped oscillation [v(m/s)]")
ax.set_ylim(-3.5, 3.5)
plt.savefig('./tmp_shortv.png')
